# %% [markdown]
# # Constraint Demo
# Inspect which sample securities are blocked by trading or compliance rules.

# %%
import pandas as pd

market = pd.read_csv('../data/sample/market_example.csv')
reference = pd.read_csv('../data/sample/reference_example.csv')
market[['ticker', 'tradable', 'upper_limit_hit', 'lower_limit_hit']].merge(reference[['ticker', 'blacklist_buy', 'blacklist_sell']], on='ticker')
