# %% [markdown]
# # Data Exploration
# Load the sample holdings, market, and reference files used by the PortfolioOS MVP.

# %%
import pandas as pd

holdings = pd.read_csv('../data/sample/holdings_example.csv')
market = pd.read_csv('../data/sample/market_example.csv')
reference = pd.read_csv('../data/sample/reference_example.csv')
holdings.merge(market, on='ticker').merge(reference, on='ticker')
